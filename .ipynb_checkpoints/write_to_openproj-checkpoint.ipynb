# %%
import pandas as pd

# %%
l_file = pd.read_csv('../../datasets/gtd.csv',sep=',', decimal='.',
header=None)

# %%
import urllib.parse
import urllib.request
import os,json
import requests

# %%
base_url = "http://localhost:8885"
url = base_url + '/api/v3/projects/gtd/work_packages'
auth_creds = 'Basic fdsafdsafs'

headers = {'Authorization' : auth_creds, 'Accept': 'application/json', 'Content-Type': 'application/json'  }

req = urllib.request.Request(url, None, headers)
response = urllib.request.urlopen(req)
the_page = response.read()
#print(the_page)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-91-f67ba8a9d156> in <module>
#       6
#       7 req = urllib.request.Request(url, None, headers)
# ----> 8 response = urllib.request.urlopen(req)
#       9 the_page = response.read()
#      10 #print(the_page)
#
# /opt/python-3.6.2/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# /opt/python-3.6.2/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#     534         return response
#
# /opt/python-3.6.2/lib/python3.6/urllib/request.py in http_response(self, request, response)
#     640         if not (200 <= code < 300):
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#     644         return response
#
# /opt/python-3.6.2/lib/python3.6/urllib/request.py in error(self, proto, *args)
#     568         if http_err:
#     569             args = (dict, 'default', 'http_error_default') + orig_args
# --> 570             return self._call_chain(*args)
#     571
#     572 # XXX probably also want an abstract factory that knows when it makes
#
# /opt/python-3.6.2/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# /opt/python-3.6.2/lib/python3.6/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     648 class HTTPDefaultErrorHandler(BaseHandler):
#     649     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 650         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     651
#     652 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 401: Unauthorized

# %%
url = base_url+'/api/v3/projects/3/work_packages'
headers = {'authorization' : auth_creds, 'accept': 'application/json', 'content-type': 'application/json'  }
for index, row in l_file.iterrows():
    task_data = {
    "subject": '"{0}"'.format(row[1]),
    "_links": {
        "project": {"href": "/api/v3/projects/3"},
        "type": {"href":"/api/v3/types/1"}
        }
    }
    print(json.dumps(task_data))
    resp = requests.post(url,data=json.dumps(task_data),headers=headers)
    #print(resp.status_code, resp.reason,resp.content)
    #print(resp.status_code, resp.reason)
# Out:
# {"subject": "\"Submit the PR Form\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Submit the passport \"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\",Fill out the form,, resume,, print salary slip,, send email,\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Get MOnika's New Passport\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Submit the form Online\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Fix Appointment go for the form filling\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Get the Recomm. Leter from V\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Get Recomm. Letter from P\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Fill out the online for\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Print out the new Salary Slip\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Collect over the missing docs\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Complete up the Ansible POC\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Connect to the qa server with ssh key\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Write down the execution plan for CR\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Get the SSH exchange done do the CR\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Explore one of the ingestions and get it done\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Complete the Onboarding dashboard\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Local request database mariadb/postgres\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Integration with JIRA\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Tableau Server CR for deploy of odbc and setting up dashboards\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Draft the CR for tableau\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"PROD openshift pipeline to deploy all from Nexus\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Draft down the firewall stuff\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Complete the Elasticsearch playbooks\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Root task for user creation\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Root task for sysctl updates\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"The tarball solution\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Nohup run and service file\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"HA config\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Authentication plugin/Nginx\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Alluxio Cloudformation Docker Playbook\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Eureka POC\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Make the rest calls to Eureka register service\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Deploy the Eureka Zuul to container in Openshift\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"From CDH invoke and update the eureka service\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Complete the cdhhadoopclluster\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Complete the sparkhadoopinstall\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Complete the single node cloudfspark\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Collibra containerization\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Check for the volume mount\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Dissect the deployment to multiple pods deploy separate\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Trifacta POC\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Finalize and update about the POC success\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Urgent burning revisions\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Nomad on Spark\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Openshift Kubernetes\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Ldap\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\",Kerberos,, kadmin,\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Kafka\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\",Glusterfs,, NAS,, NFS,, SAN,, storages,, NAT,\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"wireshark\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\",webhdfs,, httpfs,\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Get the AWS Certification\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Complete the Book study\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Complete the book practice\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Practice the online exam\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Book exam and take the exam\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Book the professional exam\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Complete practice and study for professional exam\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Complete the study for Big Data Speciality\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Complete the practice for Big Data speciality\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Book and complete the BigData Speciality certification\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Machine Learning Complete the study\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Complete the Elasticsearch playbooks\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Root task for user creation\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Root task for sysctl updates\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"The tarball solution\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Nohup run and service file\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"HA config\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Authentication plugin/Nginx\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Alluxio Cloudformation Docker Playbook\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Pull ansible from cloudform and install\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Run the playbook\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Sagemaker Alluxio ML\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Complete the Ansible SSH file upload POC\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"LDAP and Kerberos setup and completion for cdh\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Complete the ADAC Gateway\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Get the S3 buckets\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Finalize the roles and create roles for Internal access\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Finalize and create roles for vendor access\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Complete the testing\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Complete the Tableau server automation and learning\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Set up for the drivers list and get signoff\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Licenses for users\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Automation playbook for Tableau installation\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Monitoring Dashboards\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Elasticsearch setup\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Kibana\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Unravel Data\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Spring boot DevOps dashboard\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Spark Jobs for Metric Collections\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Business Dashboard project completion\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\",JIRA to be created,, tagging to be done,\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Openshift Profile should be used\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Should docker save as tarball upload to nexus\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"should tarball deployment to nexus\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"In release should download tarball and docker load\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"should untar deployment and run processing from params\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"To check for one of the clusters to deploy to QA first\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized
# {"subject": "\"Create CR for deploment get signoffs\"", "_links": {"project": {"href": "/api/v3/projects/3"}, "type": {"href": "/api/v3/types/1"}}}
# 401 Unauthorized

# %%
# ## Using urllib to perform post
    #task_data = urllib.parse.urlencode(task_data)
    #task_data = json.dumps(task_data)
    #req = urllib.request.Request(url)
    #req = urllib.request.Request(url, None, headers)
    #req.add_header('Authorization',auth_creds)
    #req.add_header('Content-Type','application/json; charset=utf-8')
    #jsondata = json.dumps(task_data)
    #jsondataasbytes = jsondata.encode('utf-8')   # needs to be bytes
    #req.add_header('Content-Length', len(jsondataasbytes))
    #response = urllib.request.urlopen(req, jsondata)
# Out:
# <Response [400]>
