# %%
from matplotlib import pyplot as plt

# %%
import pandas as pd

# %%
import numpy

# %%
years = [1950, 1960, 1970, 1980, 1990, 2000, 2010]
gdp = [300.2, 543.3, 1075.9, 2862.5, 5979.6, 10289.7, 14958.3]
# create a line chart, years on x-axis, gdp on y-axis
plt.plot(years, gdp, color='green', marker='o', linestyle='solid')
# add a title
plt.ylabel("Billions of $")
plt.title("Nominal GDP")
# add a label to the y-axis
# Out:
# Text(0.5, 1.0, 'Nominal GDP')

# %%
iris =pd.read_csv('datasets/iris.csv',sep=',', decimal='.',
header=None, names= ['sepal_length', 'sepal_width',
'petal_length', 'petal_width', 'target'])

# %%
# bars are by default width 0.8, so we'll add 0.1 to the left coordinates
# so that each bar is centered
xs = [i + 0.1 for i, _ in enumerate(iris['sepal_length'])]
plt.bar(xs,iris['petal_length'])
plt.ylabel("petal length")
plt.title("Sepal Length vs Petal Length")
plt.show()

# %%
plt.scatter(iris['petal_length'],iris['sepal_length'])
